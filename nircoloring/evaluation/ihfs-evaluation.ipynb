# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nircoloring.evaluation.utils import *
from nircoloring.evaluation.config import *

# %% [markdown]
# # IHFS - IIS Evaluation
# Evaluation IHFS as improvement to IIS

# %%
plot_grid([serengeti_night_large_nir_test, iis_serengeti_night_large_test, ihfs_serengeti_night_large_test], columns=2)

# %%
tabular_definition, copy_function = plot_grid_latex(
    [serengeti_night_large_nir_test, iis_serengeti_night_large_test, ihfs_serengeti_night_large_test],
    columns=2,
    rows=3,
    fig_title="ihfs-iis-comparison",
    column_titles=[
        "serengeti_night_large_nir_test",
        "iis_serengeti_night_large_test",
        "ihfs_serengeti_night_large_test"
    ]
)

print(tabular_definition)
#copy_function()
# Out:
# \begin{tabularx}{\textwidth}{Y Y Y Y Y Y}
#     serengeti_night_large_nir_test & iis_serengeti_night_large_test & ihfs_serengeti_night_large_test & serengeti_night_large_nir_test & iis_serengeti_night_large_test & ihfs_serengeti_night_large_test \\
#     \includegraphics{gfx/ihfs-iis-comparison/serengeti_night_large_nir_test_S2_B06_R1_PICT0196.jpg} & \includegraphics{gfx/ihfs-iis-comparison/iis_serengeti_night_large_test_S2_B06_R1_PICT0196.png} & \includegraphics{gfx/ihfs-iis-comparison/ihfs_serengeti_night_large_test_S2_B06_R1_PICT0196.png} & \includegraphics{gfx/ihfs-iis-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1370.jpg} & \includegraphics{gfx/ihfs-iis-comparison/iis_serengeti_night_large_test_S2_B06_R3_PICT1370.png} & \includegraphics{gfx/ihfs-iis-comparison/ihfs_serengeti_night_large_test_S2_B06_R3_PICT1370.png}\\
#     \includegraphics{gfx/ihfs-iis-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1377.jpg} & \includegraphics{gfx/ihfs-iis-comparison/iis_serengeti_night_large_test_S2_B06_R3_PICT1377.png} & \includegraphics{gfx/ihfs-iis-comparison/ihfs_serengeti_night_large_test_S2_B06_R3_PICT1377.png} & \includegraphics{gfx/ihfs-iis-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1383.jpg} & \includegraphics{gfx/ihfs-iis-comparison/iis_serengeti_night_large_test_S2_B06_R3_PICT1383.png} & \includegraphics{gfx/ihfs-iis-comparison/ihfs_serengeti_night_large_test_S2_B06_R3_PICT1383.png}\\
#     \includegraphics{gfx/ihfs-iis-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1428.jpg} & \includegraphics{gfx/ihfs-iis-comparison/iis_serengeti_night_large_test_S2_B06_R3_PICT1428.png} & \includegraphics{gfx/ihfs-iis-comparison/ihfs_serengeti_night_large_test_S2_B06_R3_PICT1428.png} & \includegraphics{gfx/ihfs-iis-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1451.jpg} & \includegraphics{gfx/ihfs-iis-comparison/iis_serengeti_night_large_test_S2_B06_R3_PICT1451.png} & \includegraphics{gfx/ihfs-iis-comparison/ihfs_serengeti_night_large_test_S2_B06_R3_PICT1451.png}
# \end{tabularx}

# %%
result_fid_to_df([iis_serengeti_night_large_test, ihfs_serengeti_night_large_test, unconditional_serengeti_night_large])
# Out:
#                          FID
# IIS SNL            86.674068
# IHFS SNL           83.208879
# Unconditional SNL  55.013029

# %% [markdown]
# # IHFS - CycleGAN Evaluation
# Evaluation IHFS as improvement to CycleGAN

# %%
plot_grid([serengeti_night_large_nir_test, cycle_gan_serengeti_night_large_test, ihfs_serengeti_night_large_test],
          columns=2)

# %%
tabular_definition, copy_function = plot_grid_latex(
    [serengeti_night_large_nir_test, cycle_gan_serengeti_night_large_test, ihfs_serengeti_night_large_test],
    columns=2, rows=3,
    fig_title="ihfs-cycle-gan-comparison",
    column_titles=["serengeti_night_large_nir_test",
                   "cycle_gan_serengeti_night_large_test",
                   "ihfs_serengeti_night_large_test"])

print(tabular_definition)
#copy_function()
# Out:
# \begin{tabularx}{\textwidth}{Y Y Y Y Y Y}
#     serengeti_night_large_nir_test & cycle_gan_serengeti_night_large_test & ihfs_serengeti_night_large_test & serengeti_night_large_nir_test & cycle_gan_serengeti_night_large_test & ihfs_serengeti_night_large_test \\
#     \includegraphics{gfx/ihfs-cycle-gan-comparison/serengeti_night_large_nir_test_S2_B06_R1_PICT0196.jpg} & \includegraphics{gfx/ihfs-cycle-gan-comparison/cycle_gan_serengeti_night_large_test_S2_B06_R1_PICT0196_fake.png} & \includegraphics{gfx/ihfs-cycle-gan-comparison/ihfs_serengeti_night_large_test_S2_B06_R1_PICT0196.png} & \includegraphics{gfx/ihfs-cycle-gan-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1370.jpg} & \includegraphics{gfx/ihfs-cycle-gan-comparison/cycle_gan_serengeti_night_large_test_S2_B06_R3_PICT1370_fake.png} & \includegraphics{gfx/ihfs-cycle-gan-comparison/ihfs_serengeti_night_large_test_S2_B06_R3_PICT1370.png}\\
#     \includegraphics{gfx/ihfs-cycle-gan-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1377.jpg} & \includegraphics{gfx/ihfs-cycle-gan-comparison/cycle_gan_serengeti_night_large_test_S2_B06_R3_PICT1377_fake.png} & \includegraphics{gfx/ihfs-cycle-gan-comparison/ihfs_serengeti_night_large_test_S2_B06_R3_PICT1377.png} & \includegraphics{gfx/ihfs-cycle-gan-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1383.jpg} & \includegraphics{gfx/ihfs-cycle-gan-comparison/cycle_gan_serengeti_night_large_test_S2_B06_R3_PICT1383_fake.png} & \includegraphics{gfx/ihfs-cycle-gan-comparison/ihfs_serengeti_night_large_test_S2_B06_R3_PICT1383.png}\\
#     \includegraphics{gfx/ihfs-cycle-gan-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1428.jpg} & \includegraphics{gfx/ihfs-cycle-gan-comparison/cycle_gan_serengeti_night_large_test_S2_B06_R3_PICT1428_fake.png} & \includegraphics{gfx/ihfs-cycle-gan-comparison/ihfs_serengeti_night_large_test_S2_B06_R3_PICT1428.png} & \includegraphics{gfx/ihfs-cycle-gan-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1451.jpg} & \includegraphics{gfx/ihfs-cycle-gan-comparison/cycle_gan_serengeti_night_large_test_S2_B06_R3_PICT1451_fake.png} & \includegraphics{gfx/ihfs-cycle-gan-comparison/ihfs_serengeti_night_large_test_S2_B06_R3_PICT1451.png}
# \end{tabularx}

# %%
result_fid_to_df([cycle_gan_serengeti_night_large_test, ihfs_serengeti_night_large_test])
# Out:
#                            FID
# CycleGAN SNL (Test)  74.150844
# IHFS SNL             83.208879

# %%
plot_diff_heatmap(ihfs_serengeti_night_large_test, serengeti_night_large_nir_test, columns=2, intensity=True)
plot_diff_heatmap(cycle_gan_serengeti_night_large_test, serengeti_night_large_nir_test, columns=2, intensity=True)
