# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nircoloring.evaluation.utils import *
from nircoloring.evaluation.config import *

# %% [markdown]
# # Evaluating Iterative Intensity Seeding
# Images generated by Diffusion Model using IIS on Serengeti Night Large Dataset

# %%
plot_grid([serengeti_night_large_nir_test, cycle_gan_serengeti_night_large_test,
           deoldlify_correct_size_serengeti_night_large_test, iis_serengeti_night_large_test],
          columns=2, rows=2)

# %%
tabular_definition, copy_function = plot_grid_latex(
    [serengeti_night_large_nir_test, cycle_gan_serengeti_night_large_test,
     deoldlify_correct_size_serengeti_night_large_test, iis_serengeti_night_large_test], columns=1,
    fig_title="iis-cycle-gan-comparison",
    column_titles=["serengeti_night_large_nir_test", "cycle_gan_serengeti_night_large_test",
                   "deoldify_serengeti_night_large",
                   "iis_serengeti_night_large_test"], rows=2)
print(tabular_definition)
copy_function()
# Out:
# \begin{tabularx}{\textwidth}{Y Y Y Y}
#     serengeti_night_large_nir_test & cycle_gan_serengeti_night_large_test & deoldify_serengeti_night_large & iis_serengeti_night_large_test \\
#     \includegraphics{gfx/iis-cycle-gan-comparison/serengeti_night_large_nir_test_S2_B06_R1_PICT0196.jpg} & \includegraphics{gfx/iis-cycle-gan-comparison/cycle_gan_serengeti_night_large_test_S2_B06_R1_PICT0196_fake.png} & \includegraphics{gfx/iis-cycle-gan-comparison/deoldify_serengeti_night_large_S2_B06_R1_PICT0196.png} & \includegraphics{gfx/iis-cycle-gan-comparison/iis_serengeti_night_large_test_S2_B06_R1_PICT0196.png}\\
#     \includegraphics{gfx/iis-cycle-gan-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1370.jpg} & \includegraphics{gfx/iis-cycle-gan-comparison/cycle_gan_serengeti_night_large_test_S2_B06_R3_PICT1370_fake.png} & \includegraphics{gfx/iis-cycle-gan-comparison/deoldify_serengeti_night_large_S2_B06_R3_PICT1370.png} & \includegraphics{gfx/iis-cycle-gan-comparison/iis_serengeti_night_large_test_S2_B06_R3_PICT1370.png}
# \end{tabularx}
#
# Creating /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison
# Saving /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison/serengeti_night_large_nir_test_S2_B06_R1_PICT0196.jpg
# Creating /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison
# Saving /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison/cycle_gan_serengeti_night_large_test_S2_B06_R1_PICT0196_fake.png
# Creating /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison
# Saving /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison/deoldify_serengeti_night_large_S2_B06_R1_PICT0196.png
# Creating /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison
# Saving /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison/iis_serengeti_night_large_test_S2_B06_R1_PICT0196.png
# Creating /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison
# Saving /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison/serengeti_night_large_nir_test_S2_B06_R3_PICT1370.jpg
# Creating /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison
# Saving /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison/cycle_gan_serengeti_night_large_test_S2_B06_R3_PICT1370_fake.png
# Creating /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison
# Saving /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison/deoldify_serengeti_night_large_S2_B06_R3_PICT1370.png
# Creating /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison
# Saving /home/ayk/dev/personal/uni/nir-coloring/doc/paper/gfx/gfx/iis-cycle-gan-comparison/iis_serengeti_night_large_test_S2_B06_R3_PICT1370.png

# %%
result_to_quan_df(
    [cycle_gan_serengeti_night_large_test, unconditional_serengeti_night_large, iis_serengeti_night_large_test,
     deoldlify_correct_size_serengeti_night_large_test])
# Out:
# /home/ayk/miniforge3/envs/nir-coloring/lib/python3.9/site-packages/torchvision/transforms/functional.py:152: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   img = torch.from_numpy(pic.transpose((2, 0, 1))).contiguous()
# Evaluating niqe:   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  7.61it/s]
#  20%|██        | 2/10 [00:00<00:01,  7.06it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.64it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.05it/s]
#  50%|█████     | 5/10 [00:00<00:00,  6.76it/s]
#  60%|██████    | 6/10 [00:00<00:00,  6.71it/s]
#  70%|███████   | 7/10 [00:01<00:00,  6.74it/s]
#  80%|████████  | 8/10 [00:01<00:00,  6.87it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  6.82it/s]
# 100%|██████████| 10/10 [00:01<00:00,  6.94it/s]
# Evaluating niqe:  25%|██▌       | 1/4 [00:01<00:04,  1.44s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  5.96it/s]
#  20%|██        | 2/10 [00:00<00:01,  6.31it/s]
#  30%|███       | 3/10 [00:00<00:01,  6.61it/s]
#  40%|████      | 4/10 [00:00<00:00,  6.92it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.19it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.26it/s]
#  70%|███████   | 7/10 [00:01<00:00,  7.10it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.09it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.24it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.05it/s]
# Evaluating niqe:  50%|█████     | 2/4 [00:02<00:02,  1.43s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  7.18it/s]
#  20%|██        | 2/10 [00:00<00:01,  7.64it/s]
#  30%|███       | 3/10 [00:00<00:00,  7.71it/s]
#  40%|████      | 4/10 [00:00<00:00,  7.83it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.90it/s]
#  60%|██████    | 6/10 [00:00<00:00,  7.79it/s]
#  70%|███████   | 7/10 [00:00<00:00,  7.80it/s]
#  80%|████████  | 8/10 [00:01<00:00,  7.28it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  7.16it/s]
# 100%|██████████| 10/10 [00:01<00:00,  7.43it/s]
# Evaluating niqe:  75%|███████▌  | 3/4 [00:04<00:01,  1.39s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:00<00:01,  6.63it/s]
#  20%|██        | 2/10 [00:00<00:01,  5.41it/s]
#  30%|███       | 3/10 [00:00<00:01,  5.26it/s]
#  40%|████      | 4/10 [00:00<00:01,  5.53it/s]
#  50%|█████     | 5/10 [00:00<00:00,  6.13it/s]
#  60%|██████    | 6/10 [00:00<00:00,  6.39it/s]
#  70%|███████   | 7/10 [00:01<00:00,  4.65it/s]
#  80%|████████  | 8/10 [00:01<00:00,  4.74it/s]
#  90%|█████████ | 9/10 [00:01<00:00,  5.18it/s]
# 100%|██████████| 10/10 [00:01<00:00,  5.35it/s]
# Evaluating niqe: 100%|██████████| 4/4 [00:06<00:00,  1.52s/it]
# Evaluating nrqm:   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [01:31<13:45, 91.71s/it]
#  20%|██        | 2/10 [05:51<25:24, 190.51s/it]
#  30%|███       | 3/10 [08:29<20:30, 175.77s/it]
#  40%|████      | 4/10 [11:48<18:28, 184.72s/it]
#  50%|█████     | 5/10 [12:27<11:01, 132.26s/it]
#  60%|██████    | 6/10 [15:10<09:31, 142.81s/it]
#  70%|███████   | 7/10 [18:48<08:22, 167.49s/it]
#  80%|████████  | 8/10 [22:34<06:12, 186.05s/it]
#  90%|█████████ | 9/10 [26:56<03:29, 209.83s/it]
# 100%|██████████| 10/10 [30:56<00:00, 185.70s/it]
# Evaluating nrqm:  25%|██▌       | 1/4 [30:56<1:32:50, 1857.00s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [02:23<21:30, 143.43s/it]
#  20%|██        | 2/10 [03:16<12:03, 90.38s/it]
#  30%|███       | 3/10 [04:43<10:21, 88.77s/it]
#  40%|████      | 4/10 [05:23<06:57, 69.59s/it]
#  50%|█████     | 5/10 [06:07<05:01, 60.24s/it]
#  60%|██████    | 6/10 [06:41<03:25, 51.44s/it]
#  70%|███████   | 7/10 [07:17<02:18, 46.17s/it]
#  80%|████████  | 8/10 [07:52<01:25, 42.60s/it]
#  90%|█████████ | 9/10 [08:25<00:39, 39.72s/it]
# 100%|██████████| 10/10 [09:02<00:00, 54.29s/it]
# Evaluating nrqm:  50%|█████     | 2/4 [39:59<36:07, 1083.99s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:46<06:55, 46.21s/it]
#  20%|██        | 2/10 [02:24<10:15, 76.97s/it]
#  30%|███       | 3/10 [03:31<08:27, 72.46s/it]
#  40%|████      | 4/10 [05:24<08:49, 88.23s/it]
#  50%|█████     | 5/10 [07:22<08:14, 98.93s/it]
#  60%|██████    | 6/10 [08:59<06:33, 98.41s/it]
#  70%|███████   | 7/10 [09:41<04:00, 80.01s/it]
#  80%|████████  | 8/10 [10:17<02:11, 65.80s/it]
#  90%|█████████ | 9/10 [10:57<00:58, 58.03s/it]
# 100%|██████████| 10/10 [11:38<00:00, 69.86s/it]
# Evaluating nrqm:  75%|███████▌  | 3/4 [51:38<15:08, 908.03s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:34<05:06, 34.10s/it]
#  20%|██        | 2/10 [01:13<04:57, 37.17s/it]
#  30%|███       | 3/10 [01:57<04:43, 40.55s/it]
#  40%|████      | 4/10 [02:35<03:56, 39.41s/it]
#  50%|█████     | 5/10 [03:15<03:17, 39.47s/it]
#  60%|██████    | 6/10 [03:53<02:36, 39.01s/it]
#  70%|███████   | 7/10 [04:27<01:52, 37.48s/it]
#  80%|████████  | 8/10 [05:08<01:17, 38.55s/it]
#  90%|█████████ | 9/10 [05:49<00:39, 39.37s/it]
# 100%|██████████| 10/10 [06:30<00:00, 39.05s/it]
# Evaluating nrqm: 100%|██████████| 4/4 [58:09<00:00, 872.25s/it]
#                             NIQE      NRQM         FID
# CycleGAN SNL (Test)    14.058509  5.452130   74.150844
# Unconditional SNL      14.771756  5.093936   55.013029
# IIS SNL                14.083268  4.928783   86.674068
# DeOldify Correct Size  17.927709  4.406037  104.066262
