# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nircoloring.evaluation.utils import *
from nircoloring.evaluation.config import *

# %% [markdown]
# # Evaluating Iterative Intensity Seeding
# Images generated by Diffusion Model using IIS on Serengeti Night Large Dataset

# %%
plot_grid([serengeti_night_large_nir_test, cycle_gan_serengeti_night_large_test, iis_serengeti_night_large_test],
          columns=3, rows=6)

# %%
tabular_definition, copy_function = plot_grid_latex(
    [serengeti_night_large_nir_test, cycle_gan_serengeti_night_large_test, iis_serengeti_night_large_test], columns=2,
    fig_title="diffusion-sampling-intensity-qual-new",
    column_titles=["serengeti_night_large_nir_test", "cycle_gan_serengeti_night_large_test",
                   "iis_serengeti_night_large_test"], rows=2)
print(tabular_definition)
#copy_function()
# Out:
# \begin{tabularx}{\textwidth}{Y Y Y Y Y Y}
#     serengeti_night_large_nir_test & cycle_gan_serengeti_night_large_test & iis_serengeti_night_large_test & serengeti_night_large_nir_test & cycle_gan_serengeti_night_large_test & iis_serengeti_night_large_test \\
#     \includegraphics{gfx/diffusion-sampling-intensity-qual-new/serengeti_night_large_nir_test_S2_B06_R1_PICT0196.jpg} & \includegraphics{gfx/diffusion-sampling-intensity-qual-new/cycle_gan_serengeti_night_large_test_S2_B06_R1_PICT0196_fake.png} & \includegraphics{gfx/diffusion-sampling-intensity-qual-new/iis_serengeti_night_large_test_S2_B06_R1_PICT0196.png} & \includegraphics{gfx/diffusion-sampling-intensity-qual-new/serengeti_night_large_nir_test_S2_B06_R3_PICT1370.jpg} & \includegraphics{gfx/diffusion-sampling-intensity-qual-new/cycle_gan_serengeti_night_large_test_S2_B06_R3_PICT1370_fake.png} & \includegraphics{gfx/diffusion-sampling-intensity-qual-new/iis_serengeti_night_large_test_S2_B06_R3_PICT1370.png}\\
# ...

# %%
result_fid_to_df(
    [cycle_gan_serengeti_night_large_test, unconditional_serengeti_night_large, iis_serengeti_night_large_test])
# Out:
#                            FID
# CycleGAN SNL (Test)  74.150844
# Unconditional SNL    55.013029
# IIS SNL              86.674068
