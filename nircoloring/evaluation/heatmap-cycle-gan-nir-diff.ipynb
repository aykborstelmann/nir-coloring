# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nircoloring.evaluation.utils import *
from nircoloring.evaluation.config import *

# %%
plot_diff_heatmap(cycle_gan_serengeti_night_large_test, serengeti_night_large_nir_test, columns=2, rows=2, intensity=True)

# %%
plot_diff_heatmap_for_latex(cycle_gan_serengeti_night_large_test, serengeti_night_large_nir_test, columns=2, rows=2, intensity=True, save_dir=join(ROOT_DIR, "doc/paper/gfx/heatmap-nir-cyclegan-intensity-diff"))
